# %%
# %pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.67-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Collecting nvidia-ml-py>=12.0.0 (from ultralytics)
#   Downloading nvidia_ml_py-13.610.43-py3-none-any.whl.metadata (9.7 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.5.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.67-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.5 MB/s eta 0:00:0000:01
# Downloading nvidia_ml_py-13.610.43-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 3.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-ml-py, ultralytics-thop, ultralytics
# Successfully installed nvidia-ml-py-13.610.43 ultralytics-8.4.67 ultralytics-thop-2.0.20

# %%
from ultralytics import YOLO
from google.colab import drive
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model = YOLO('yolo26n.pt')

# %%
caminho_imagem = "content/drive/MyDrive/computer-vision-lab/dataset/images/video1.mp4"
# Out:
# video 1/1 (frame 37/713) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 12 persons, 6 cars, 2 buss, 1 truck, 4 traffic lights, 1 backpack, 2470.0ms
# video 1/1 (frame 38/713) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 11 persons, 6 cars, 1 bus, 1 truck, 4 traffic lights, 1 backpack, 2466.7ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_27069/1890269040.py in <cell line: 0>()
#       1 caminho_imagem = "/content/drive/MyDrive/computer_vision_lab/images/video1.mp4"
# ----> 2 resultado = model(caminho_imagem)
#       3 print(resultado)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __call__(self, source, stream, **kwargs)
#     175             ...     print(f"Detected {len(r)} objects in image")
#     176         """
# --> 177         return self.predict(source, stream, **kwargs)
#     178
#     179     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     535         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     536             self.predictor.set_prompts(prompts)
# --> 537         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     538
#     539     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     226             return self.stream_inference(source, model, *args, **kwargs)
#     227         else:
# --> 228             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Results into one
#     229
#     230     def predict_cli(self, source=None, model=None):
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in generator_context(*args, **kwargs)
#      59                     # Pass the last request to the generator and get its response
#      60                     with ctx_factory():
# ---> 61                         response = gen.send(request)
#      62
#      63         # We let the exceptions raised above by the generator's `.throw` or
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     335                 # Inference
#     336                 with profilers[1]:
# --> 337                     preds = self.inference(im, *args, **kwargs)
#     338                     if self.args.embed:
#     339                         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in inference(self, im, *args, **kwargs)
#     183             else False
#     184         )
# --> 185         return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#     186
#     187     def pre_transform(self, im: list[np.ndarray]) -> list[np.ndarray]:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/autobackend.py in forward(self, im, augment, visualize, embed, **kwargs)
#     277             forward_kwargs = {"augment": augment, "visualize": visualize, "embed": embed, **kwargs}
#     278
# --> 279         y = self.backend.forward(im, **forward_kwargs)
#     280
#     281         if isinstance(y, (list, tuple)):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/backends/pytorch.py in forward(self, im, augment, visualize, embed, **kwargs)
#      88             (torch.Tensor | list[torch.Tensor]): Model predictions as tensor(s).
#      89         """
# ---> 90         return self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#      91
#      92
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in forward(self, x, *args, **kwargs)
#     142         if isinstance(x, dict):  # for cases of training and validating while training.
#     143             return self.loss(x, *args, **kwargs)
# --> 144         return self.predict(x, *args, **kwargs)
#     145
#     146     def predict(self, x, profile=False, visualize=False, augment=False, embed=None):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in predict(self, x, profile, visualize, augment, embed)
#     159         if augment:
#     160             return self._predict_augment(x)
# --> 161         return self._predict_once(x, profile, visualize, embed)
#     162
#     163     def _predict_once(self, x, profile=False, visualize=False, embed=None):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in _predict_once(self, x, profile, visualize, embed)
#     181             if profile:
#     182                 self._profile_one_layer(m, x, dt)
# --> 183             x = m(x)  # run
#     184             y.append(x if m.i in self.save else None)  # save output
#     185             if visualize:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/conv.py in forward_fuse(self, x)
#      87             (torch.Tensor): Output tensor.
#      88         """
# ---> 89         return self.act(self.conv(x))
#      90
#      91
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     551
#     552     def forward(self, input: Tensor) -> Tensor:
# --> 553         return self._conv_forward(input, self.weight, self.bias)
#     554
#     555
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     546             )
#     547
# --> 548         return F.conv2d(
#     549             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#
150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 9 persons, 3 cars, 1 truck, 1 traffic light, 207.8ms
# video 1/1 (frame 122/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 8 persons, 4 cars, 1 truck, 1 traffic light, 219.3ms
# video 1/1 (frame 123/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 6 persons, 3 cars, 1 truck, 2 traffic lights, 262.5ms
# video 1/1 (frame 124/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 6 persons, 4 cars, 2 traffic lights, 222.5ms
# video 1/1 (frame 125/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 6 persons, 4 cars, 2 traffic lights, 222.4ms
# video 1/1 (frame 126/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 6 persons, 4 cars, 1 traffic light, 226.3ms
# video 1/1 (frame 127/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 5 persons, 3 cars, 2 traffic lights, 156.3ms
# video 1/1 (frame 128/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 6 persons, 5 cars, 1 bus, 1 traffic light, 157.5ms
# video 1/1 (frame 129/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 3 persons, 4 cars, 1 traffic light, 146.5ms
# video 1/1 (frame 130/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 4 persons, 4 cars, 1 truck, 1 traffic light, 138.8ms
# video 1/1 (frame 131/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 3 persons, 3 cars, 2 trucks, 2 traffic lights, 162.7ms
# video 1/1 (frame 132/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 4 persons, 3 cars, 1 truck, 2 traffic lights, 146.7ms
# video 1/1 (frame 133/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 3 persons, 3 cars, 1 bus, 1 truck, 2 traffic lights, 148.4ms
# video 1/1 (frame 134/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 3 persons, 3 cars, 1 bus, 2 traffic lights, 143.5ms
# video 1/1 (frame 135/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 3 cars, 1 bus, 1 truck, 2 traffic lights, 154.3ms
# video 1/1 (frame 136/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 4 cars, 1 truck, 2 traffic lights, 177.1ms
# video 1/1 (frame 137/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 3 cars, 1 truck, 2 traffic lights, 153.8ms
# video 1/1 (frame 138/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 3 persons, 4 cars, 1 bus, 2 traffic lights, 153.9ms
# video 1/1 (frame 139/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 6 cars, 1 bus, 2 traffic lights, 158.8ms
# video 1/1 (frame 140/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 5 cars, 1 bus, 1 traffic light, 153.2ms
# video 1/1 (frame 141/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 5 cars, 1 bus, 2 traffic lights, 163.8ms
# video 1/1 (frame 142/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 3 cars, 1 bus, 2 traffic lights, 139.2ms
# video 1/1 (frame 143/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 3 persons, 5 cars, 1 bus, 2 traffic lights, 142.6ms
# video 1/1 (frame 144/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 4 cars, 1 bus, 2 traffic lights, 148.5ms
# video 1/1 (frame 145/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 2 cars, 1 bus, 2 traffic lights, 142.5ms
# video 1/1 (frame 146/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 2 cars, 1 bus, 2 traffic lights, 139.4ms
# video 1/1 (frame 147/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 3 cars, 1 bus, 2 traffic lights, 134.8ms
# video 1/1 (frame 148/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 3 cars, 1 bus, 2 traffic lights, 145.6ms
# video 1/1 (frame 149/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 2 persons, 3 cars, 1 bus, 2 traffic lights, 141.9ms
# video 1/1 (frame 150/150) /content/drive/MyDrive/computer_vision_lab/images/video1.mp4: 384x640 3 persons, 2 cars, 1 bus, 2 traffic lights, 135.0ms
# Speed: 6.1ms preprocess, 193.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict

# %%
# plota o resultado da detecção
resultado_anotado = resultados[0].plot()

# converter de BGR para RGB para exibir corretamente com matplotlib
resultado_anotado_rgb = cv2.cvtColor(resultado_anotado, cv2.COLOR_BGR2RGB)

# exibir a imagem anotada
plt.figure(figsize=(10, 10))
plt.imshow(resultado_anotado_rgb)
