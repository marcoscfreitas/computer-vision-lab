# %%
from torch import torch_version
import torch
from ultralytics import YOLO

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(DEVICE)
# Out:
# cuda

# %%
model = YOLO("yolo26n.pt")

resultado = model(source="yolo.jpeg", save = True)
# Out:
# image 1/1 /home/marv/Documentos/computer-vision-lab/yolo.jpeg: 480x640 1 bicycle, 1 truck, 1 dog, 11.1ms
# Speed: 2.6ms preprocess, 11.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /home/marv/Documentos/computer-vision-lab/runs/detect/predict
